# %% [markdown]
# # Stellar cluster plot examples

# %%
# initialization
import numpy as np
import sys
import os
import matplotlib
import yt

# directory/file
datadir = os.path.expanduser(
    "~/test_data/haloD_varSFE_Lfid_Salp_ks20231024"
)  # data directory

step = 273
infofile = "output_%05d/info_%05d.txt" % (int(step), int(step))
infofile_fp = os.path.abspath(datadir + "/" + infofile)  # full path
logsfc = np.loadtxt(os.path.join(datadir, "logSFC"))

# %%
# read data
FIELDS = [
    "Density",
    "x-velocity",
    "y-velocity",
    "z-velocity",
    "Pressure",
    "Metallicity",
    "xHI",
    "xHII",
    "xHeII",
    "xHeIII",
]
EPF = [
    ("particle_family", "b"),
    ("particle_tag", "b"),
    ("particle_birth_epoch", "d"),
    ("particle_metallicity", "d"),
]
print(infofile_fp)
# loading data
ds = yt.load(infofile_fp, fields=FIELDS, extra_particle_fields=EPF)
ad = ds.all_data()
# Out:
# yt : [INFO     ] 2024-02-16 16:10:50,495 Parameters: current_time              = 4.311420483661945
# yt : [INFO     ] 2024-02-16 16:10:50,496 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2024-02-16 16:10:50,497 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-02-16 16:10:50,498 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2024-02-16 16:10:50,498 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2024-02-16 16:10:50,499 Parameters: current_redshift          = 12.171087046255657
# yt : [INFO     ] 2024-02-16 16:10:50,499 Parameters: omega_lambda              = 0.685000002384186
# yt : [INFO     ] 2024-02-16 16:10:50,499 Parameters: omega_matter              = 0.314999997615814
# yt : [INFO     ] 2024-02-16 16:10:50,499 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2024-02-16 16:10:50,500 Parameters: hubble_constant           = 0.674000015258789
# /home/fabg/test_data/haloD_varSFE_Lfid_Salp_ks20231024/output_00273/info_00273.txt
# yt : [WARNING  ] 2024-02-16 16:10:52,253 This output has no cooling fields
# yt : [WARNING  ] 2024-02-16 16:10:52,709 The DM particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,710 The star particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,710 The cloud particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,711 The dust particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,711 The star_tracer particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,711 The cloud_tracer particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,711 The dust_tracer particle filter already exists. Overriding.
# yt : [WARNING  ] 2024-02-16 16:10:52,711 The gas_tracer particle filter already exists. Overriding.
# yt : [INFO     ] 2024-02-16 16:10:52,712 Adding particle_type: DM
# yt : [INFO     ] 2024-02-16 16:10:52,721 Adding particle_type: star
# yt : [INFO     ] 2024-02-16 16:10:52,731 Adding particle_type: cloud
# yt : [INFO     ] 2024-02-16 16:10:52,741 Adding particle_type: dust
# yt : [INFO     ] 2024-02-16 16:10:52,752 Adding particle_type: star_tracer
# yt : [INFO     ] 2024-02-16 16:10:52,761 Adding particle_type: cloud_tracer
# yt : [INFO     ] 2024-02-16 16:10:52,782 Adding particle_type: dust_tracer
# yt : [INFO     ] 2024-02-16 16:10:52,802 Adding particle_type: gas_tracer

# %%
ad["SFC","particle_position_x"]
# Out:
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 ad["SFC","particle_position_x"]
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/yt/data_objects/data_containers.py:229, in YTDataContainer.__getitem__(self, key)
#     225 def __getitem__(self, key):
#     226     """
#     227     Returns a single field.  Will add if necessary.
#     228     """
# --> 229     f = self._determine_fields([key])[0]
#     230     if f not in self.field_data and key not in self.field_data:
#     231         if f in self._container_fields:
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/yt/data_objects/data_containers.py:1465, in YTDataContainer._determine_fields(self, fields)
#    1462     explicit_fields.append(field)
#    1463     continue
# -> 1465 finfo = self.ds._get_field_info(field)
#    1466 ftype, fname = finfo.name
#    1467 # really ugly check to ensure that this field really does exist somewhere,
#    1468 # in some naming convention, before returning it as a possible field type
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/yt/data_objects/static_output.py:962, in Dataset._get_field_info(self, field)
#     957 def _get_field_info(
#     958     self,
#     959     field: Union[FieldKey, ImplicitFieldKey, DerivedField],
#     960     /,
#     961 ) -> DerivedField:
# --> 962     field_info, candidates = self._get_field_info_helper(field)
#     964     if field_info.name[1] in ("px", "py", "pz", "pdx", "pdy", "pdz"):
#     965         # escape early as a bandaid solution to
#     966         # https://github.com/yt-project/yt/issues/3381
#     967         return field_info
#
# File ~/.pyenv/versions/3.8.10/lib/python3.8/site-packages/yt/data_objects/static_output.py:1055, in Dataset._get_field_info_helper(self, field)
#    1052 elif (ftype, fname) in self.field_info:
#    1053     return self.field_info[ftype, fname], []
# -> 1055 raise YTFieldNotFound(field, ds=self)
#
# YTFieldNotFound: Could not find field ('SFC', 'particle_position_x') in info_00217.
# Did you mean:
# 	('DM', 'particle_position_x')
# 	('all', 'particle_position_x')
# 	('cloud', 'particle_position_x')
# 	('cloud_tracer', 'particle_position_x')
# 	('dust', 'particle_position_x')
# 	('dust_tracer', 'particle_position_x')
# 	('gas_tracer', 'particle_position_x')
# 	('io', 'particle_position_x')
# 	('nbody', 'particle_position_x')
# 	('sink', 'particle_position_x')
# 	('star', 'particle_position_x')
# 	('star_tracer', 'particle_position_x')

# %%
ad.keys()
# Out:
# dict_keys([])

# %%
centeroid = np.array([np.mean(ad["star", "particle_position_x"]), 
                      np.mean(ad["star", "particle_position_y"]), 
                      np.mean(ad["star", "particle_position_z"])])
print(centeroid)
# Out:
# [0.49117112 0.49277624 0.49474927]

# %%
# plot
width = (300, "pc")  # plot width

p = yt.SlicePlot(ds, "z", "density", width=width, center=centeroid)
p.annotate_particles(
    width=width, ptype="star", p_size=20.0, marker=".", col="r"
)  # Pop II stars
# p.annotate_particles(
#     width=width, ptype="SFC", p_size=100.0, marker="x", col="b"
# )  # star forming clouds (test particles)
# p.annotate_particles(
#     width=width, ptype="PSC", p_size=100.0, marker="x", col="g"
# )  # passive stellar clusters (test particles)
p.annotate_timestamp(redshift=True, redshift_format='z = {redshift:.6f}')

p.set_figure_size(5)
p.show()
# Out:
# yt : [INFO     ] 2024-02-16 16:10:36,752 xlim = 0.491132 0.491210
# yt : [INFO     ] 2024-02-16 16:10:36,752 ylim = 0.492738 0.492815
# yt : [INFO     ] 2024-02-16 16:10:36,754 xlim = 0.491132 0.491210
# yt : [INFO     ] 2024-02-16 16:10:36,755 ylim = 0.492738 0.492815
# yt : [INFO     ] 2024-02-16 16:10:36,760 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
_, _, redshift, _, rsfc, msfc, nstar, mstar, nh, Zmetal, posx, poxy, posz = logsfc.T

# %%
print(redshift)
# Out:
# [21.87759 21.74784 21.71574 21.70353 21.69973 16.84611 16.76253 16.76025
#  16.76005 16.75398 16.75368 16.74683 16.45536 16.44131 16.24241 16.23941
#  16.19564 16.19564 14.15616 13.72564 13.72518 13.72411 13.65782 13.5795
#  13.5269  13.52432 13.50889 13.50441 13.47057 13.46545 13.42777 13.18611
#  13.10678 13.0956  12.85742 12.85503 12.84073 12.82681 12.82577 12.62062
#  12.61858 12.60119 12.51477 12.43043 12.40401 12.38916 12.38903 12.38776
#  12.38667 12.38584 12.38093 12.38017 12.37989 12.37932 12.37838 12.37772
#  12.37491 12.37219 12.3691  12.36901 12.36783 12.36656 12.36617 12.36548
#  12.36509 12.36452 12.36289 12.36077 12.36062 12.35896 12.35865 12.35175
#  12.35036 12.3468  12.34508 12.34184 12.3297  12.32625 12.32582 12.32077
#  12.3136  12.30887 12.29627 12.26847 12.26499 12.26176 12.25105 12.25052
#  12.24911 12.24847 12.24835 12.24782 12.24682 12.2455  12.24477 12.2438
#  12.24377 12.24371 12.2433  12.243   12.24281 12.24265 12.24258 12.24216
#  12.24191 12.2417  12.24154 12.24135 12.24114 12.24102 12.23959 12.23916
#  12.23827 12.2381  12.23795 12.23774 12.23686 12.23672 12.23636 12.23571
#  12.23551 12.23515 12.23452 12.23428 12.23351 12.23328 12.23263 12.23227
#  12.23034 12.22996 12.22931 12.22931 12.22919 12.22902 12.22649 12.22541
#  12.22505 12.22434 12.22389 12.22184 12.21992 12.21652 12.21617 12.21541
#  12.21503 12.21494 12.21448 12.21439 12.21412 12.21398 12.21215 12.21201
#  12.21191 12.21173 12.21152 12.21071 12.21022 12.20998 12.20909 12.20837
#  12.20813 12.20747 12.20624 12.2055  12.20538 12.20482 12.20471 12.20459
#  12.20455 12.20406 12.20404 12.20157 12.20116 12.20113 12.20098 12.20075
#  12.20052 12.19808 12.19689 12.19533 12.19431 12.19417 12.19322 12.19287
#  12.18913 12.18765 12.18685 12.18642 12.18468 12.18389 12.18158 12.17417
#  12.1739  12.17328 12.17319 12.17273 12.17209 12.17136 12.17065 12.17052
#  12.17049 12.17033 12.16973 12.1695  12.16847 12.16801 12.1678  12.1675
#  12.16604 12.16499 12.16429 12.16427 12.16261 12.16127 12.15945 12.15923
#  12.15918 12.15641 12.15623 12.15359 12.15135 12.14901 12.14894 12.14823
#  12.14756 12.14657 12.14627]

# %%
new_cluster = np.argmin(np.abs(redshift - 12.16499))

# %%
redshift[new_cluster]
# Out:
# 12.16499

# %%
print("mass of cloud [msun] = {:.2E}".format(msfc[new_cluster]))
# Out:
# mass of cloud [msun] = 1.29E+05

# %%
print("mass of star cluster [msun] = {:.2E}".format(mstar[new_cluster]))
# Out:
# mass of star cluster [msun] = 1.03E+05

# %%
mstar[new_cluster]/msfc[new_cluster]
# Out:
# 0.7995337995337995

# %%
print("density of cloud [cm ^ -3]", nh[new_cluster])
# Out:
# density of cloud [cm ^ -3] 32960.0

# %%
print("radius of cloud pc", rsfc[new_cluster])
# Out:
# radius of cloud pc 3.068
